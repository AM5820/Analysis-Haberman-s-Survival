# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scipy.stats as sp

# %%
data =  pd.read_csv('haberman.csv')
data.sample(5)
# Out:
#      Age  Operation_year  positive_axillary_nodes  Survival_status
# 256   64              61                        0                1
# 275   67              66                        0                1
# 217   59              63                        0                1
# 146   52              61                        0                1
# 77    44              63                        1                1

# %%
data.replace({1:1,2:0},inplace=True)

# %%
data.sample(5)
# Out:
#      Age  Operation_year  positive_axillary_nodes  Survival_status
# 86    45              64                        0                1
# 50    41              69                        8                1
# 242   62              66                        0                1
# 142   52              69                        3                0
# 200   57              64                        9                1

# %%
data.Survival_status.value_counts()
# Out:
# 1    225
# 0     81
# Name: Survival_status, dtype: int64

# %%
survived = data[data['Survival_status'] ==1]
died = data[data['Survival_status'] ==0]

# %%
plt.figure(figsize=(8,8))
plt.pie([len(survived),len(died)],labels=['Survived','Died'],autopct='%.2f%%',textprops={'size':15})
plt.show()

# %%
sns.barplot(['Died','Survived'],[len(died),len(survived)])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(18,7))
sns.countplot(data.Age)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data.describe()
# Out:
#               Age  Operation_year  positive_axillary_nodes  Survival_status
# count  306.000000      306.000000               306.000000       306.000000
# mean    52.457516       62.852941                 3.895425         0.735294
# std     10.803452        3.249405                 7.243460         0.441899
# min     30.000000       58.000000                 0.000000         0.000000
# 25%     44.000000       60.000000                 0.000000         0.000000
# 50%     52.000000       63.000000                 0.000000         1.000000
# 75%     60.750000       65.750000                 4.000000         1.000000
# max     83.000000       69.000000                52.000000         1.000000

# %%
print(survived.describe())
print(died.describe())
# Out:
#               Age  Operation_year  positive_axillary_nodes  Survival_status
# count  225.000000      225.000000               225.000000            225.0
# mean    52.017778       62.862222                 2.657778              1.0
# std     11.012154        3.222915                 5.909530              0.0
# min     30.000000       58.000000                 0.000000              1.0
# 25%     43.000000       60.000000                 0.000000              1.0
# 50%     52.000000       63.000000                 0.000000              1.0
# 75%     60.000000       66.000000                 3.000000              1.0
# max     77.000000       69.000000                46.000000              1.0
#              Age  Operation_year  positive_axillary_nodes  Survival_status
# count  81.000000       81.000000                81.000000             81.0
# mean   53.679012       62.827160                 7.333333              0.0
# ...

# %%
plt.figure(figsize=(9,8))
sns.boxplot(x=data.Survival_status,y=data.positive_axillary_nodes)
plt.show()

# %%
plt.figure(figsize=(9,9))
sns.violinplot(x=data.Survival_status,y=data.positive_axillary_nodes)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.swarmplot(x=data.Survival_status,y=data.positive_axillary_nodes)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 30.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(15,8))
sns.distplot(survived.positive_axillary_nodes,label='Survived')
sns.distplot(died.positive_axillary_nodes,label='Died')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,7))
sns.kdeplot(survived.positive_axillary_nodes,shade=True,color='blue',label='Survived')
sns.kdeplot(died.positive_axillary_nodes,shade=True,color='red',label='Died')
plt.title('Density Curve  --Survived Vs Died')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(7,7))
ax1 = fig.add_subplot(122)
plt.scatter(survived.Age,survived.positive_axillary_nodes,c='green')
ax1.set_label('Survived')
ax2 = fig.add_subplot(121)
plt.scatter(died.Age,died.positive_axillary_nodes,color='red')
ax1.set_label('Died')
plt.show()

# %%
fig = plt.figure(figsize=(23,5))
ax1 = fig.add_subplot(121)
sns.countplot(survived.positive_axillary_nodes,ax=ax1)
ax1.set_title('Survived')

ax2 = fig.add_subplot(122)
sns.countplot(died.positive_axillary_nodes,ax=ax2)
ax2.set_title('Died')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x=data.Survival_status,y=data.Age)
plt.title('Age vs Survival Status')
plt.show()

# %%
sns.pairplot(data,hue='Survival_status',size=4)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Modeling

# %%
X = data.iloc[:, [0,2]].values
y = data.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components=1)
X_train = lda.fit_transform(X_train,y_train)
X_test = lda.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print(f'Accuracy = {round(classifier.score(X_test,y_test)*100,1)}%')
# Out:
# Accuracy = 62.9%
